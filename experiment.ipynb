# %%
import json
import datetime

# %%
class abc:
    def __init__(self, i, cat, amt, desc, date):
        self.i = i
        self.cat = cat
        self.amt = amt
        self.desc = desc
        self.date = date
    def getItems(self):
        # return f'{self.i}, {self.cat}, {self.amt}, {self.desc}, {self.date}'
        return [self.i, self.cat, self.amt, self.desc, self.date]
exp = abc(1, "Food", 2000, "Pizza", datetime.date.today().isoformat())

# %%
exp_dict = {
    'Id':exp.i,
    'Category':exp.cat,
    'Amount':exp.amt,
    'Description':exp.desc,
    'Date':exp.date
}
json.dumps(exp_dict, separators=(',',':'))
# Out:
# '{"Id":1,"Category":"Food","Amount":2000,"Description":"Pizza","Date":"2026-06-01"}'

# %%
'AsHar'.lower()
# Out:
# 'ashar'

# %%
['ash', 'imT', 'Me'].lower()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 ['ash', 'imT', 'Me'].lower()
#
# AttributeError: 'list' object has no attribute 'lower'
